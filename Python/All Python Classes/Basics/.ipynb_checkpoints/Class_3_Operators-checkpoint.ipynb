# %% [markdown]
# # Logical Operator
#
# ##### and
# ##### or
# ##### not

# %% [raw]
# # and
#
# True True = True
# True False = False
# False False = False
# False True = False

# %% [raw]
# # or
#
#
# True True = True
# True False = True
# False False = False
# False True = True

# %% [markdown]
# >	Greater than	x > y
# <	Less than	x < y

# %%
a=10
b=20

# %%
(a>6)
# Out:
# True

# %%
b < 7
# Out:
# False

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
((a>10) or (b>7))
# Out:
# True

# %%
print(True and True)
# Out:
# True

# %%
print(False or True)
# Out:
# True

# %%
a = False

# %%
not(a)
# Out:
# True

# %% [markdown]
# & --- and
#
# | --- or

# %%
a = 50
b = 4

# %%
x = [1,2,3,4,5]

# %%
a in x
# Out:
# False

# %%
2 in x
# Out:
# True

# %%
1 in x
# Out:
# True

# %%
b in x
# Out:
# True

# %%
a
# Out:
# 50

# %%
a not in x
# Out:
# True

# %% [raw]
# +	Addition	x + y
# -	Subtraction	x - y
# *	Multiplication	x * y
# /	Division	x / y
# %	Modulus	x % y
# **	Exponentiation	x ** y
# //	Floor division	x // y

# %%
49%5
# Out:
# 4

# %%
2 ** 4
# Out:
# 16

# %%
2 ** 10
# Out:
# 1024

# %%
14/5
# Out:
# 2.8

# %%
14//5
# Out:
# 2

# %%
85 / 8
# Out:
# 10.625

# %%
85 // 8
# Out:
# 10

# %%
9%5        # remainder
# Out:
# 4

# %%
2**5
# Out:
# 32

# %%
89//5
# Out:
# 17

# %%
89/5
# Out:
# 17.8

# %% [markdown]
# ## Assignment Operators

# %% [raw]
# =	                 x = 5  ->	x = 5
# +=	                 x += 3 ->   x = x + 3
# -=	                 x -= 3 ->	x = x - 3
# *=	                 x *= 3 ->	x = x * 3
# /=	                 x /= 3 ->	x = x / 3
# %=	                 x %= 3 ->	x = x % 3
# //=                  x //= 3 ->	x = x // 3
# **=	                 x **= 3 ->	x = x ** 3

# %%
a = 5

# %%
a = a + 5      # a += 5
a
# Out:
# 15

# %%
a += 10  # a = a + 10
a
# Out:
# 25

# %%
q = 2

# %%
q += 6     # q = q+6
q
# Out:
# 8

# %%
a
# Out:
# 25

# %%
a -= 1  # a = a - 1

# %%
a
# Out:
# 24

# %%
a *= 2
a
# Out:
# 48

# %%
a
# Out:
# 48

# %%
a /= 2

# %%
a = 325

# %%
a //= 2
a
# Out:
# 162

# %%
a = 2

# %%
a **= 5      #power   a = a ** 5

# %%
a
# Out:
# 32

# %%
56//5
# Out:
# 11

# %% [markdown]
# ==	Equal	x == y
# !=	Not equal	x != y
# >	Greater than	x > y
# <	Less than	x < y
# >=	Greater than or equal to	x >= y
# <=

# %%
a
# Out:
# 32

# %%
a == 32
# Out:
# True

# %%
2 * 10 == 20
# Out:
# True

# %%
5 != 6
# Out:
# True

# %%
a
# Out:
# 32

# %%
5 >= 5
# Out:
# True

# %%
10 <= 5
# Out:
# False

# %%
x = [1, 2, 3, 4, 5]
x
# Out:
# [1, 2, 3, 4, 5]

# %%
2 in x
# Out:
# True

# %%
9 in x
# Out:
# False

# %%
9 not in x
# Out:
# True

# %%
y = [1, 2, 3, 4]

# %%
x == y
# Out:
# False

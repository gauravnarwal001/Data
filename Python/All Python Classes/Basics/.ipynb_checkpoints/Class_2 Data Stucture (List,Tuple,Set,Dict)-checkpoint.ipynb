# %% [markdown]
# ## List - []
#
# - Creation: Lists are created using square brackets [ ] and separating elements with commas.     lst =  [4,9,78,'asdf']
# - Mutable (changeable)
# - Accessing Elements: Elements in a list can be accessed using index notation, starting from 0. - lst[5]
# - Modifying Lists: Lists are mutable, so you can change, add, or remove elements.
# - Slicing: You can slice lists to get sublists [::]
# - Methods and Operations: Lists have many built-in methods like append(), extend(), insert(), remove(), pop(), count(), etc.
#
#
#
# ### Tuples - ()
# - Definition: Tuples are ordered, immutable (unchangeable), and can contain elements of different data types.
# - Creation: Tuples are created using parentheses () and separating elements with commas.
# - Accessing Elements: Elements in a tuple can be accessed using index notation, starting from 0, similar to lists.
# - Immutable Nature: Once created, the elements in a tuple cannot be changed.
# - Methods and Operations: Tuples have fewer built-in methods compared to lists due to their immutability.
#
#
# ### Dictionaries - my_dict = {'name': 'John', 'age': 30, 'city': 'New York'}
#
# - Definition: Dictionaries are unordered, mutable (changeable), and indexed collections of key-value pairs.
# - Creation: Dictionaries are created using curly braces {} and key-value pairs separated by colons
# - Accessing Elements: Elements in a dictionary are accessed using keys rather than indices. - print(my_dict['name'])
# - Modifying Elements: You can modify, add, or remove elements in a dictionary.
# - Methods and Operations: Dictionaries have various built-in methods like keys(), values(), items(), get(), update(), pop(), popitem(), etc.
#
#
#
# ### Sets -  my_set = {1, 2, 3, 'a', 'b', 'c'}
# - Definition: Sets are unordered, mutable (changeable), and do not allow duplicate elements.
# - Creation: Sets are created using curly braces {} and separating elements with commas
# - Adding and Removing Elements: You can add elements using the add() method and remove elements using the remove() or discard() method.
# - Methods and Operations: Sets have built-in methods like add(), remove(), discard(), clear(), copy(), union(), intersection(), difference(), symmetric_difference(), etc.
# - Indexing : Not Allowed
# - Slicing : Not Allowed

# %% [markdown]
# # List

# %%
l = []

# %%
type(l)
# Out:
# list

# %%
l1 = [1,2,3,4987654,5, "Raj" , "Abhishek" ,345.565, True,[3,4,5,6]]
l1
# Out:
# [1, 2, 3, 4987654, 5, 'Raj', 'Abhishek', 345.565, True, [3, 4, 5, 6]]

# %%
l1[3:8]
# Out:
# [4987654, 5, 'Raj', 'Abhishek', 345.565]

# %%
l1[5]
# Out:
# 'Raj'

# %%
l1
# Out:
# [1, 2, 10, 4987654, 5, 'Raj', 'Abhishek', 345.565, True, [3, 4, 5, 6]]

# %%
l1[6] = "Python"

# %%
l1
# Out:
# [1, 2, 10, 4987654, 5, 'Raj', 'Python', 345.565, True, [3, 4, 5, 6]]

# %%
for i in range(1,len(l1),2):
    l1[i] = 0

# %%
l1
# Out:
# [1, 0, 10, 0, 5, 0, 'Python', 0, True, 0]

# %%
l1[2] = 10

# %%
l1
# Out:
# [1, 0, 10, 0, 5, 0, 'Python', 0, True, 0]

# %% [markdown]
# ## Tuples

# %%
t = ()

# %%
type(t)
# Out:
# tuple

# %%
t = (1,5,8,9,3,"abc")

# %%
t
# Out:
# (1, 5, 8, 9, 3, 'abc')

# %%
t[-3] = 90
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22372\2657793449.py in <module>
# ----> 1 t[-3] = 90
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1 = (5,6,7,8,9,[4,6,7])
t1
# Out:
# (5, 6, 7, 8, 9, [4, 6, 7])

# %%
t1[5][1] = 60

# %%
t1
# Out:
# (5, 6, 7, 8, 9, [4, 60, 7])

# %%
z = [t]
z
# Out:
# [(1, 5, 8, 9, 3, 'abc')]

# %%
z[0][2]
# Out:
# 8

# %%
len(l1)
# Out:
# 10

# %%
t = (9,5,7,6,4,1)
t
# Out:
# (9, 5, 7, 6, 4, 1)

# %% [markdown]
# ## Sets

# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s = {80,9,7,1,2,3,4,4,4,4,4}

# %%
s
# Out:
# {1, 2, 3, 4, 7, 9, 80}

# %%
l
# Out:
# [68, 8, 5, 78, 6, 4, 6, 2, 1, 2, 3, 1, 2, 1]

# %%
s = {5,100,1,2,3,89,4,1,2,3,"ABC"}
s
# Out:
# {1, 100, 2, 3, 4, 5, 89, 'ABC'}

# %%
type(s)
# Out:
# set

# %%
s[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22372\2635755408.py in <module>
# ----> 1 s[2]
#
# TypeError: 'set' object is not subscriptable

# %%
tuple(s)
# Out:
# (1, 2, 3, 100, 5, 4, 'ABC', 89)

# %%
list(s)
# Out:
# [1, 2, 3, 100, 5, 4, 'ABC', 89]

# %%
s[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22372\2635755408.py in <module>
# ----> 1 s[2]
#
# TypeError: 'set' object is not subscriptable

# %%
s[-3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6056\1338137100.py in <module>
# ----> 1 s[-3]
#
# TypeError: 'set' object is not subscriptable

# %%
type(s)
# Out:
# set

# %% [raw]
# list()
# tuple()
# set()
# dict()

# %%
s
# Out:
# {1, 100, 2, 3, 4, 5, 89, 'ABC'}

# %%
change_set = tuple(s)
change_set
# Out:
# (1, 2, 3, 100, 5, 4, 'ABC', 89)

# %%
change_set[5]
# Out:
# 4

# %%
s1 = {9,8,1,2,3,4,5,5,5,5,5}
s1
# Out:
# {1, 2, 3, 4, 5, 8, 9}

# %%
type(s1)
# Out:
# set

# %% [markdown]
# # Dict

# %%
d= {}

# %%
type(d)
# Out:
# dict

# %%
d = {'name':"Python","age":20,"Marks":10}

# %%
d
# Out:
# {'name': 'Python', 'age': 20, 'Marks': 10}

# %%
d['name']
# Out:
# 'Python'

# %%
d['deepanshu'] = 123456

# %%
d
# Out:
# {'name': 'Python', 'age': 20, 'Marks': 10, 'deepanshu': 123456}

# %%
d['python'] = 90

# %%
d
# Out:
# {'name': 'Python', 'age': 20, 'Marks': 10, 'deepanshu': 123456, 'python': 90}

# %%
d['python'] = 100

# %%
d
# Out:
# {'name': 'Python', 'age': 20, 'Marks': 10, 'deepanshu': 123456, 'python': 100}

# %%
d1 = {'name' : "Mohit" ,"subject" :["data science " , "big data " , "data analytics"] , "number" :43242424}

# %%
d1
# Out:
# {'name': 'Mohit',
#  'subject': ['data science ', 'big data ', 'data analytics'],
#  'number': 43242424}

# %%
d4 = {'course': ['dsa', 'java', 'webdev', 'blockchain', 'cloud'],
 'mentor': ('gaurav', 'krishna', 'aditiya', 'vinay', 'sunny '),
 'price': {3500, 11000, 15000, 20000},
 'duration': 1,
 'access year': 1,
 'syllabus': {'python': ['core python',
   'oops',
   'pandas',
   'numpy',
   'db',
   'mongodb'],
  'ml': ['supervised', 'unsupervised', 'semisupervised']}}

# %%
d4['course'][-1] = "Python"

# %%
d4
# Out:
# {'course': ['dsa', 'java', 'webdev', 'blockchain', 'Python'],
#  'mentor': ('gaurav', 'krishna', 'aditiya', 'vinay', 'sunny '),
#  'price': {3500, 11000, 15000, 20000},
#  'duration': 1,
#  'access year': 1,
#  'syllabus': {'python': ['core python',
#    'oops',
#    'pandas',
#    'numpy',
#    'db',
#    'mongodb'],
#   'ml': ['supervised', 'unsupervised', 'semisupervised']}}

# %%
list(d4['mentor'])
# Out:
# ['gaurav', 'krishna', 'aditiya', 'vinay', 'sunny ']

# %%
n = list(d4['mentor'])
n
# Out:
# ['gaurav', 'krishna', 'aditiya', 'vinay', 'sunny ']

# %%
n[-1] = "ABC"

# %%
d4['mentor'] = tuple(n)

# %%
d4
# Out:
# {'course': ['dsa', 'java', 'webdev', 'blockchain', 'Python'],
#  'mentor': ('gaurav', 'krishna', 'aditiya', 'vinay', 'ABC'),
#  'price': {3500, 11000, 15000, 20000},
#  'duration': 1,
#  'access year': 1,
#  'syllabus': {'python': ['core python',
#    'oops',
#    'pandas',
#    'numpy',
#    'db',
#    'mongodb'],
#   'ml': ['supervised', 'unsupervised', 'semisupervised']}}

# %%
d4
# Out:
# {'course': ['dsa', 'java', 'python', 'blockchain', 'cloud'],
#  'mentor': ('gaurav', 'krishna', 'aditiya', 'vinay', 'sunny '),
#  'price': {3500, 11000, 15000, 20000},
#  'duration': 1,
#  'access year': 1,
#  'syllabus': {'python': ['core python',
#    'oops',
#    'pandas',
#    'numpy',
#    'db',
#    'mongodb'],
#   'ml': ['supervised', 'unsupervised', 'semisupervised']}}

# %% [markdown]
# # 1.string
# # 2.list
# # 3.tuple
# # 4.set
# # 5.dict

# %%
s1 = "This is my python class"

# %%
s1.find("p")
# Out:
# 11

# %%
s1.count("s")
# Out:
# 4

# %%
s1.index("z")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13892\2723690859.py in <module>
# ----> 1 s1.index("z")
#
# ValueError: substring not found

# %%
s1.find("z")
# Out:
# -1

# %%
s1.count('y')
# Out:
# 2

# %%
s1.index("i",3)
# Out:
# 5

# %%
s1.find("p")
# Out:
# 11

# %%
s1
# Out:
# 'This is my python class'

# %%
s1.upper()
# Out:
# 'THIS IS MY PYTHON CLASS'

# %%
s1.lower()
# Out:
# 'this is my python class'

# %%
s2 = "this is my python class"

# %%
s2.capitalize()
# Out:
# 'This is my python class'

# %%
s2.title()
# Out:
# 'This Is My Python Class'

# %%
s2
# Out:
# 'this is my python class'

# %%
s2.split()
# Out:
# ['this', 'is', 'my', 'python', 'class']

# %%
s2
# Out:
# 'this is my python class'

# %%
s2.split("s")
# Out:
# ['thi', ' i', ' my python cla', '', '']

# %%
s2.split("i")
# Out:
# ['th', 's ', 's my python class']

# %%
x= s2.split("i")
x
# Out:
# ['th', 's ', 's my python class']

# %%
l = ["A","B","C","D"]

# %%
"".join(l)
# Out:
# 'ABCD'

# %%
"*".join(l)
# Out:
# 'A*B*C*D'

# %%
s2
# Out:
# 'this is my python class'

# %%
s2.replace(" ","_")
# Out:
# 'this_is_my_python_class'

# %%
s3 = "my name,is, gaurav,narwal"

# %%
s3.split(",")
# Out:
# ['my name', 'is', ' gaurav', 'narwal']

# %%
split_list = ['manisha','ankur','sahil']

# %%
"_".join(split_list)
# Out:
# 'manisha_ankur_sahil'

# %%
" ".join(x)
# Out:
# 'th s  s my python class'

# %%
l = ['gaurav',"mohit",'Rohit','asdf','bhumika','Esha']

# %%
"".join(l)
# Out:
# 'gauravmohitRohitasdfbhumikaEsha'

# %%
s5 = "     Python    abc          "

# %%
s5.strip()
# Out:
# 'Python    abc'

# %%
s5.lstrip()
# Out:
# 'Python    abc          '

# %%
s5.rstrip()
# Out:
# '     Python    abc'

# %%
s1 = "5274asd"

# %%
s1.isnumeric()
# Out:
# False

# %%
s1.islower()
# Out:
# True

# %%
s1.isalnum()
# Out:
# True

# %%
s1.isupper()
# Out:
# False

# %%
s1.isalpha()
# Out:
# False

# %%
s1.isnumeric()
# Out:
# False

# %%
s1.isalnum()
# Out:
# True

# %% [markdown]
# # List Methods

# %%
l1 = [1, 2, 3, 4, 5, 'Gaurav', 'Narwal', 345.565, True, [3, 4, 5, 6]]

# %%
l2 = [3, 4, 5, 'Nikhil', 'monu']

# %%
l1
# Out:
# [1, 2, 3, 4, 5, 'Gaurav', 'Narwal', 345.565, True, [3, 4, 5, 6]]

# %%
l2
# Out:
# [3, 4, 5, 'Nikhil', 'monu']

# %%
l2.append("Rahul")

# %%
l2
# Out:
# [3, 4, 5, 'Nikhil', 'monu']

# %%
l2.insert(2,"Suyash")

# %%
l2
# Out:
# [3, 4, 'Suyash', 5, 'Nikhil', 'monu']

# %%
l1 + l2
# Out:
# [1,
#  2,
#  3,
#  4,
#  5,
#  'Gaurav',
#  'Narwal',
#  345.565,
#  True,
#  [3, 4, 5, 6],
#  3,
#  4,
#  'Suyash',
#  5,
#  'Nikhil',
#  'monu']

# %%
l1.append(l2)

# %%
l1
# Out:
# [1,
#  2,
#  3,
#  4,
#  5,
#  'Gaurav',
#  'Narwal',
#  345.565,
#  True,
#  [3, 4, 5, 6],
#  [3, 4, 'Suyash', 5, 'Nikhil', 'monu']]

# %%
l1.extend(l2)

# %%
l1
# Out:
# [1,
#  2,
#  3,
#  4,
#  5,
#  'Gaurav',
#  'Narwal',
#  345.565,
#  True,
#  [3, 4, 5, 6],
#  [3, 4, 'Suyash', 5, 'Nikhil', 'monu'],
#  3,
#  4,
#  'Suyash',
#  5,
#  'Nikhil',
#  'monu']

# %%
l1.append("Gunjan")

# %%
l1
# Out:
# [1, 2, 3, 4, 5, 'Gaurav', 'Narwal', 345.565, True, [3, 4, 5, 6], 'Gunjan']

# %%
l1.insert(3,"Himanshu")

# %%
l1
# Out:
# [1,
#  2,
#  3,
#  'Himanshu',
#  4,
#  5,
#  'Gaurav',
#  'Narwal',
#  345.565,
#  True,
#  [3, 4, 5, 6],
#  'Gunjan']

# %%
l2
# Out:
# [3, 4, 5, 'Nikhil', 'monu']

# %%
l1 + l2
# Out:
# [1,
#  2,
#  3,
#  'Himanshu',
#  4,
#  5,
#  'Gaurav',
#  'Narwal',
#  345.565,
#  True,
#  [3, 4, 5, 6],
#  'Gunjan',
#  3,
#  4,
#  5,
#  'Nikhil',
#  'monu']

# %%
l1.append(l2)

# %%
l1
# Out:
# [1,
#  2,
#  3,
#  'Himanshu',
#  4,
#  5,
#  'Gaurav',
#  'Narwal',
#  345.565,
#  True,
#  [3, 4, 5, 6],
#  'Gunjan',
#  [3, 4, 5, 'Nikhil', 'monu']]

# %%
l1.extend(l2)

# %%
l1
# Out:
# [1, 2, 3, 4, 5, 'Gaurav', 'Narwal', 345.565, True, [3, 4, 5, 6, 'ABC']]

# %%
l1.pop()
# Out:
# True

# %%
l1
# Out:
# [1, 2, 3, 4, 5, 'Gaurav', 'Narwal', 345.565]

# %%
l1.pop(2)
# Out:
# 3

# %%
l1
# Out:
# [1, 2, 4, 5, 'Gaurav', 'Narwal', 345.565]

# %%
l1.count(5)
# Out:
# 1

# %%
l1
# Out:
# [1, 2, 4, 5, 'Gaurav', 'Narwal', 345.565]

# %%
l1.clear()

# %%
l1
# Out:
# []

# %%
del l1

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13892\2585568370.py in <module>
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
z = [1,8,6,7,2,2,2,2,2]

# %%
z.count(2)
# Out:
# 5

# %%
z.sort()

# %%
z
# Out:
# [1, 2, 2, 2, 2, 2, 6, 7, 8]

# %%
z.sort(reverse=True)

# %%
z
# Out:
# [8, 7, 6, 2, 2, 2, 2, 2, 1]

# %% [markdown]
# # Tuple Functions

# %%
t = (9, 5,7, 7, 6, 4, 1,5,9,6, 7)

# %%
t
# Out:
# (9, 5, 7, 7, 6, 4, 1, 5, 9, 6, 7)

# %%
t.count(7)
# Out:
# 3

# %%
t.index(1)
# Out:
# 6

# %%
t.

# %% [markdown]
# # Sets

# %%
s={3,4,54,6,6,43,3,3,3,5,5,6}

# %%
# Out:
# {3, 4, 5, 6, 43, 54}

# %%
s.add(50)

# %%
s
# Out:
# {3, 4, 5, 6, 43, 50, 54}

# %%
s.add(1)

# %%
s
# Out:
# {1, 3, 4, 5, 6, 43, 50, 54}

# %%
s.add(40)

# %%
s
# Out:
# {1, 3, 4, 5, 6, 40, 43, 50, 54}

# %%
s.discard(6)

# %%
s
# Out:
# {1, 3, 4, 5, 40, 43, 50, 54}

# %%
s.pop()
# Out:
# 3

# %%
s
# Out:
# {4, 5, 40, 43, 50, 54}

# %%
s.discard(40)

# %%
s
# Out:
# {4, 43, 50, 54}

# %%
s.remove(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6660\1954191563.py in <module>
# ----> 1 s.remove(5)
#
# KeyError: 5

# %%
s
# Out:
# {4, 43, 50, 54}

# %%
s.remove(66)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16512\819061111.py in <module>
# ----> 1 s.remove(66)
#
# KeyError: 66

# %%
s.discard(66)

# %%
s
# Out:
# {1, 3, 5, 6, 43, 50, 54}

# %%
s.pop()
# Out:
# 1

# %%
s
# Out:
# {3, 5, 6, 43, 50, 54}

# %%
s.discard(5)

# %%
s
# Out:
# {3, 6, 43, 50, 54}

# %%
s.pop()
# Out:
# 3

# %%
s
# Out:
# {6, 43, 50, 54}

# %%
s = {1,2,3,4,85,85,41,58}

# %%
s
# Out:
# {1, 2, 3, 4, 41, 58, 85}

# %%
s.remove(4)

# %%
s
# Out:
# {1, 2, 3, 41, 58, 85}

# %%
s.discard(54)

# %%
s
# Out:
# {1, 2, 3, 41, 58, 85}

# %%
s.remove(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16512\2383628386.py in <module>
# ----> 1 s.remove(50)
#
# KeyError: 50

# %%
s.add(80)

# %%
s
# Out:
# {1, 2, 3, 41, 58, 80, 85}

# %%
s.pop()
# Out:
# 80

# %%
s
# Out:
# {1, 2, 3, 41, 58, 85}

# %%
s.remove(58)

# %%
s
# Out:
# {1, 2, 3, 41, 85}

# %% [markdown]
# # Dict Functions

# %%
d1 = {'name': 'Gaurav',
 'subject': ['data science ', 'big data ', 'data analytics'],
 'number': 43242424}

# %%
d1
# Out:
# {'name': 'Gaurav',
#  'subject': ['data science ', 'big data ', 'data analytics'],
#  'number': 43242424}

# %%
d1.keys()
# Out:
# dict_keys(['name', 'subject', 'number'])

# %%
d1.values()
# Out:
# dict_values(['Gaurav', ['data science ', 'big data ', 'data analytics'], 43242424])

# %%
d1.items()
# Out:
# dict_items([('name', 'Gaurav'), ('subject', ['data science ', 'big data ', 'data analytics']), ('number', 43242424)])

# %%
d1['name']
# Out:
# 'Gaurav'

# %%
d1.get('name')
# Out:
# 'Gaurav'

# %%
d1
# Out:
# {'name': 'Gaurav',
#  'subject': ['data science ', 'big data ', 'data analytics'],
#  'number': 43242424}

# %%
d1.pop('number')
# Out:
# 43242424

# %%
d1
# Out:
# {'name': 'Gaurav', 'subject': ['data science ', 'big data ', 'data analytics']}

# %%
d1['city'] = 123

# %%
d1
# Out:
# {'name': 'Gaurav',
#  'subject': ['data science ', 'big data ', 'data analytics'],
#  'city': 123}

# %%
d4 = {'course': ['dsa', 'java', 'webdev', 'blockchain', 'cloud'],
 'mentor': ('gaurav', 'krishna', 'aditiya', 'vinay', 'sunny '),
 'price': {3500, 11000, 15000, 20000},
 'duration': 1,
 'access year': 1,
 'syllabus': {'python': ['core python',
   'oops',
   'pandas',
   'numpy',
   'db',
   'mongodb'],
  'ml': ['supervised', 'unsupervised', 'semisupervised']},
 'course ': ['dsa', 'java', 'webdev', 'blockchain', 'cloud', 'python']}

# %%
d4
# Out:
# {'course': ['dsa', 'java', 'webdev', 'blockchain', 'cloud'],
#  'mentor': ('gaurav', 'krishna', 'aditiya', 'vinay', 'sunny '),
#  'price': {3500, 11000, 15000, 20000},
#  'duration': 1,
#  'access year': 1,
#  'syllabus': {'python': ['core python',
#    'oops',
#    'pandas',
#    'numpy',
#    'db',
#    'mongodb'],
#   'ml': ['supervised', 'unsupervised', 'semisupervised']},
#  'course ': ['dsa', 'java', 'webdev', 'blockchain', 'cloud', 'python']}

# %%
d4['course'].append("python")

# %%
d4
# Out:
# {'course': ['dsa', 'java', 'webdev', 'blockchain', 'cloud', 'python'],
#  'mentor': ('gaurav', 'krishna', 'aditiya', 'vinay', 'sunny '),
#  'price': {3500, 11000, 15000, 20000},
#  'duration': 1,
#  'access year': 1,
#  'syllabus': {'python': ['core python',
#    'oops',
#    'pandas',
#    'numpy',
#    'db',
#    'mongodb'],
#   'ml': ['supervised', 'unsupervised', 'semisupervised']},
#  'course ': ['dsa', 'java', 'webdev', 'blockchain', 'cloud', 'python']}

# %%
import 
            word = input("What is your favourite word? ")
            if len(word) <=2:
                print("Length of word is too short, password could not be generated.")
                print("Sorry for the inconvenience.")
            else:
                print("Thank you")
                print("Your password is", animal[0], animal[1], animal[2], len(country), word[0], word[1], word[2], len(animal), len(word))
                print("It is time to select a game.")
                print("Would you like to select 'Guess the number' or 'Rock Paper Scissors?")
                while b <= 10000:
                    ch = input("You want to play Yes or No :- ").lower()
                    if ch == "no":
                        break
                    choice1 = input("Type 1 for 'Guess the number' or 2 for 'Rock Paper Scissors'. ")

                    if choice1 == '1':
                        number = random.randint(1,100)
                        print("Welcome to Guess the number.")
                        print("In this game, you will have to guess a number from 1-100.")
                        print("Every time you get it wrong, it will say if the correct number is higher or lower than the number that you chose.")
                        print("When you guess it correctly, it display that.")
                        while b <= 1000:
                            guess = int(input("What is your guess?"))
                            if guess == number:
                                print("Well done. You managed to guess the number in", b,"guess(es)")
                                b = 1
                                break
                            elif guess <= number:
                                print("Your guess is lower than the correct number. Try again")
                                b = b+1
                                continue
                            else:
                                print("Your guess was higher than the correct number. Try again")
                                b = b+1
                                continue
                    else:
                        if choice1 == '2':
                            game2 = random.randint(1,3)
                            print("Welcome to Rock Paper Scissors.")
                            print("In this game, you will have to choose between Rock, Paper and Scissors.")
                            print("All you have to do is type in your choice.")
                            print("It will tell you if you won, lost or tied.")
                            guess2 = input("What is your choice?")
                            if guess2 == 'Rock':
                                guess2 = 1
                                if guess2 == game2:
                                    print("I chose Rock")
                                    print("It is a draw!")
                                else:
                                    if game2 == 2:
                                        print("I choose Paper")
                                        print("You lose!")
                                    else:
                                        print("I chose Scissors")
                                        print("You win!")
                            else:
                                if guess2 == 'Paper':
                                    guess2 = 2
                                    if guess2 == game2:
                                        print("I chose Paper")
                                        print("It is a draw!")
                                    else:
                                        if guess2 <= game2:
                                            print("I chose Scissors")
                                            print("You lose!")
                                        else:
                                            print("I chose Rock")
                                            print("You win!")
                                else:
                                    guess2 = 3
                                    if guess2 == game2:
                                        print("I chose Scissors")
                                        print("It is a draw!")
                                    else:
                                        if game2 == 1:
                                            print("I chose Rock")
                                            print("You lose!")
                                        else:
                                            print("I chose Paper")
                                            print("You win!")
                        else:
                            print("That is not an option.")
                            print("Please try again.")
# Out:
# Welcome to algerime!
# The first step is to set up a username and password.
# What is your first name? asdf
# Thank you
# What is your second name? sddsaf
# Thank you
# What year were you born? a
# Year of birth is too low, username could not be generated.

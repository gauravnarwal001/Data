# %%
import pandas as pd

# %%
df = pd.read_csv('Bank_churn.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
df.tail(7)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9993       9994    15569266     Rahman          644    France    Male   28
# 9994       9995    15719294       Wood          800    France  Female   29
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9993       7  155060.41              1          1               0
# 9994       2       0.00              2          0               0
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# ...

# %%
df.sample(10)
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 7498       7499    15659031  Mordvinova          630    France  Female   36
# 8123       8124    15608956          Su          711    France    Male   33
# 1975       1976    15591386    Golubova          622    France  Female   35
# 2693       2694    15627697  Alekseyeva          662    France    Male   34
# 275         276    15758685    Dubinina          706     Spain  Female   37
# 6105       6106    15605134        Bond          617    France  Female   34
# 5766       5767    15740846         Wei          556    France    Male   40
# 4990       4991    15802857      Robson          659     Spain  Female   33
# 6310       6311    15641595    Jonathan          685     Spain    Male   43
# 406         407    15578045    Mitchell          538     Spain  Female   49
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df['Geography']         # df.Geography
# Out:
# 0        France
# 1         Spain
# 2        France
# 3        France
# 4         Spain
#          ...
# 9995     France
# 9996     France
# 9997     France
# 9998    Germany
# 9999     France
# Name: Geography, Length: 10000, dtype: object

# %%
type(df.Geography)
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df[['RowNumber','Geography','Age']]
# Out:
#       RowNumber Geography  Age
# 0             1    France   42
# 1             2     Spain   41
# 2             3    France   42
# 3             4    France   39
# 4             5     Spain   43
# ...         ...       ...  ...
# 9995       9996    France   39
# 9996       9997    France   35
# 9997       9998    France   36
# 9998       9999   Germany   42
# 9999      10000    France   28
#
# [10000 rows x 3 columns]

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Geography'].nunique()
# Out:
# 3

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df.rename(columns = {'Geography':'Location'},inplace = True)

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Location  Gender  Age  \
# 0             1    15634602   Hargrave          619   France  Female   42
# 1             2    15647311       Hill          608    Spain  Female   41
# 2             3    15619304       Onio          502   France  Female   42
# 3             4    15701354       Boni          699   France  Female   39
# 4             5    15737888   Mitchell          850    Spain  Female   43
# ...         ...         ...        ...          ...      ...     ...  ...
# 9995       9996    15606229   Obijiaku          771   France    Male   39
# 9996       9997    15569892  Johnstone          516   France    Male   35
# 9997       9998    15584532        Liu          709   France  Female   36
# 9998       9999    15682355  Sabbatini          772  Germany    Male   42
# 9999      10000    15628319     Walker          792   France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.sort_values(['Age'],ascending = False)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Location  Gender  Age  \
# 6443       6444    15764927       Rogova          753   France    Male   92
# 6759       6760    15660878        T'ien          705   France    Male   92
# 2458       2459    15813303      Rearick          513    Spain    Male   88
# 3033       3034    15578006          Yao          787   France  Female   85
# 3387       3388    15798024         Lori          537  Germany    Male   84
# ...         ...         ...          ...          ...      ...     ...  ...
# 9782       9783    15728829       Weigel          509   France    Male   18
# 2141       2142    15758372      Wallace          674   France    Male   18
# 9501       9502    15634146          Hou          835  Germany    Male   18
# 9520       9521    15673180  Onyekaozulu          727  Germany  Female   18
# 1619       1620    15770309     McDonald          656   France    Male   18
#
# ...

# %%
df['Bhoomi'] = 0

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Location  Gender  Age  \
# 0             1    15634602   Hargrave          619   France  Female   42
# 1             2    15647311       Hill          608    Spain  Female   41
# 2             3    15619304       Onio          502   France  Female   42
# 3             4    15701354       Boni          699   France  Female   39
# 4             5    15737888   Mitchell          850    Spain  Female   43
# ...         ...         ...        ...          ...      ...     ...  ...
# 9995       9996    15606229   Obijiaku          771   France    Male   39
# 9996       9997    15569892  Johnstone          516   France    Male   35
# 9997       9998    15584532        Liu          709   France  Female   36
# 9998       9999    15682355  Sabbatini          772  Germany    Male   42
# 9999      10000    15628319     Walker          792   France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df['Bonus'] = df['EstimatedSalary'] * 2

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Location  Gender  Age  \
# 0             1    15634602   Hargrave          619   France  Female   42
# 1             2    15647311       Hill          608    Spain  Female   41
# 2             3    15619304       Onio          502   France  Female   42
# 3             4    15701354       Boni          699   France  Female   39
# 4             5    15737888   Mitchell          850    Spain  Female   43
# ...         ...         ...        ...          ...      ...     ...  ...
# 9995       9996    15606229   Obijiaku          771   France    Male   39
# 9996       9997    15569892  Johnstone          516   France    Male   35
# 9997       9998    15584532        Liu          709   France  Female   36
# 9998       9999    15682355  Sabbatini          772  Germany    Male   42
# 9999      10000    15628319     Walker          792   France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
null_df = df.describe(include = 'all')
null_df
# Out:
#           RowNumber    CustomerId Surname   CreditScore Location Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000    10000  10000
# unique          NaN           NaN    2932           NaN        3      2
# top             NaN           NaN   Smith           NaN   France   Male
# freq            NaN           NaN      32           NaN     5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800      NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299      NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000      NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000      NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000      NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000      NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000      NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# ...

# %%
null_df.isna().sum()
# Out:
# RowNumber          3
# CustomerId         3
# Surname            7
# CreditScore        3
# Location           7
# Gender             7
# Age                3
# Tenure             3
# Balance            3
# NumOfProducts      3
# HasCrCard          3
# IsActiveMember     3
# EstimatedSalary    3
# Exited             3
# Bhoomi             3
# Bonus              3
# dtype: int64

# %%
null_df.fillna(0,inplace = True)

# %%
null_df
# Out:
#           RowNumber    CustomerId Surname   CreditScore Location Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000    10000  10000
# unique      0.00000  0.000000e+00    2932      0.000000        3      2
# top         0.00000  0.000000e+00   Smith      0.000000   France   Male
# freq        0.00000  0.000000e+00      32      0.000000     5014   5457
# mean     5000.50000  1.569094e+07       0    650.528800        0      0
# std      2886.89568  7.193619e+04       0     96.653299        0      0
# min         1.00000  1.556570e+07       0    350.000000        0      0
# 25%      2500.75000  1.562853e+07       0    584.000000        0      0
# 50%      5000.50000  1.569074e+07       0    652.000000        0      0
# 75%      7500.25000  1.575323e+07       0    718.000000        0      0
# max     10000.00000  1.581569e+07       0    850.000000        0      0
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# ...

# %%
null_df = df.describe(include = 'all')
null_df
# Out:
#           RowNumber    CustomerId Surname   CreditScore Location Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000    10000  10000
# unique          NaN           NaN    2932           NaN        3      2
# top             NaN           NaN   Smith           NaN   France   Male
# freq            NaN           NaN      32           NaN     5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800      NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299      NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000      NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000      NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000      NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000      NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000      NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# ...

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Location  Gender  Age  \
# 0             1    15634602   Hargrave          619   France  Female   42
# 1             2    15647311       Hill          608    Spain  Female   41
# 2             3    15619304       Onio          502   France  Female   42
# 3             4    15701354       Boni          699   France  Female   39
# 4             5    15737888   Mitchell          850    Spain  Female   43
# ...         ...         ...        ...          ...      ...     ...  ...
# 9995       9996    15606229   Obijiaku          771   France    Male   39
# 9996       9997    15569892  Johnstone          516   France    Male   35
# 9997       9998    15584532        Liu          709   France  Female   36
# 9998       9999    15682355  Sabbatini          772  Germany    Male   42
# 9999      10000    15628319     Walker          792   France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.drop(3)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Location  Gender  Age  \
# 0             1    15634602   Hargrave          619   France  Female   42
# 1             2    15647311       Hill          608    Spain  Female   41
# 2             3    15619304       Onio          502   France  Female   42
# 4             5    15737888   Mitchell          850    Spain  Female   43
# 5             6    15574012        Chu          645    Spain    Male   44
# ...         ...         ...        ...          ...      ...     ...  ...
# 9995       9996    15606229   Obijiaku          771   France    Male   39
# 9996       9997    15569892  Johnstone          516   France    Male   35
# 9997       9998    15584532        Liu          709   France  Female   36
# 9998       9999    15682355  Sabbatini          772  Germany    Male   42
# 9999      10000    15628319     Walker          792   France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
sample_df = df.sample(30)
sample_df
# Out:
#       RowNumber  CustomerId       Surname  CreditScore Location  Gender  Age  \
# 1087       1088    15696098       Palermo          498   France  Female   31
# 3357       3358    15670668          Webb          658  Germany    Male   29
# 4394       4395    15669175         Ts'ai          479  Germany    Male   24
# 1819       1820    15712319    Chukwukere          714    Spain    Male   45
# 2456       2457    15591766      Crawford          607    Spain  Female   25
# 3411       3412    15815628        Moysey          711   France  Female   37
# 1010       1011    15799811       Herrera          724   France    Male   40
# 8897       8898    15740442           May          603   France    Male   51
# 1224       1225    15628298     Johnstone          500    Spain  Female   47
# 7435       7436    15647898       Russell          610    Spain  Female   50
# 1109       1110    15616330          Liao          595   France    Male   31
# ...

# %%
sample_df.reset_index(drop = True)
# Out:
#     RowNumber  CustomerId       Surname  CreditScore Location  Gender  Age  \
# 0        1088    15696098       Palermo          498   France  Female   31
# 1        3358    15670668          Webb          658  Germany    Male   29
# 2        4395    15669175         Ts'ai          479  Germany    Male   24
# 3        1820    15712319    Chukwukere          714    Spain    Male   45
# 4        2457    15591766      Crawford          607    Spain  Female   25
# 5        3412    15815628        Moysey          711   France  Female   37
# 6        1011    15799811       Herrera          724   France    Male   40
# 7        8898    15740442           May          603   France    Male   51
# 8        1225    15628298     Johnstone          500    Spain  Female   47
# 9        7436    15647898       Russell          610    Spain  Female   50
# 10       1110    15616330          Liao          595   France    Male   31
# ...

# %%
sample_df
# Out:
#       RowNumber  CustomerId       Surname  CreditScore Location  Gender  Age  \
# 1087       1088    15696098       Palermo          498   France  Female   31
# 3357       3358    15670668          Webb          658  Germany    Male   29
# 4394       4395    15669175         Ts'ai          479  Germany    Male   24
# 1819       1820    15712319    Chukwukere          714    Spain    Male   45
# 2456       2457    15591766      Crawford          607    Spain  Female   25
# 3411       3412    15815628        Moysey          711   France  Female   37
# 1010       1011    15799811       Herrera          724   France    Male   40
# 8897       8898    15740442           May          603   France    Male   51
# 1224       1225    15628298     Johnstone          500    Spain  Female   47
# 7435       7436    15647898       Russell          610    Spain  Female   50
# 1109       1110    15616330          Liao          595   France    Male   31
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
duplicate_df = df[['Location','Gender']]
duplicate_df
# Out:
#      Location  Gender
# 0      France  Female
# 1       Spain  Female
# 2      France  Female
# 3      France  Female
# 4       Spain  Female
# ...       ...     ...
# 9995   France    Male
# 9996   France    Male
# 9997   France  Female
# 9998  Germany    Male
# 9999   France  Female
#
# [10000 rows x 2 columns]

# %%
duplicate_df.duplicated().sum()
# Out:
# 9994

# %%
bhoomi_df = duplicate_df.drop_duplicates()
bhoomi_df
# Out:
#    Location  Gender
# 0    France  Female
# 1     Spain  Female
# 5     Spain    Male
# 6    France    Male
# 7   Germany  Female
# 15  Germany    Male

# %%
bhoomi_df.to_csv('Bhoomi_file.csv')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Location  Gender  Age  \
# 0             1    15634602   Hargrave          619   France  Female   42
# 1             2    15647311       Hill          608    Spain  Female   41
# 2             3    15619304       Onio          502   France  Female   42
# 3             4    15701354       Boni          699   France  Female   39
# 4             5    15737888   Mitchell          850    Spain  Female   43
# ...         ...         ...        ...          ...      ...     ...  ...
# 9995       9996    15606229   Obijiaku          771   France    Male   39
# 9996       9997    15569892  Johnstone          516   France    Male   35
# 9997       9998    15584532        Liu          709   France  Female   36
# 9998       9999    15682355  Sabbatini          772  Germany    Male   42
# 9999      10000    15628319     Walker          792   France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
group_df = df.groupby(['Location'])[['EstimatedSalary']].count()
group_df
# Out:
#           EstimatedSalary
# Location
# France               5014
# Germany              2509
# Spain                2477

# %%
group_df.reset_index()
# Out:
#   Location  EstimatedSalary
# 0   France             5014
# 1  Germany             2509
# 2    Spain             2477

# %%
pd.merge()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14528\700432438.py in <module>
# ----> 1 pd.merge()
#
# TypeError: merge() missing 2 required positional arguments: 'left' and 'right'

# %% [markdown]
# # Joins

# %%
join_df = df.head(40)[['CustomerId','Gender','Age','Balance']]
join_df = join_df.sample(10)
join_df
# Out:
#     CustomerId  Gender  Age    Balance
# 9     15592389    Male   27  134603.88
# 22    15699309  Female   38       0.00
# 3     15701354  Female   39       0.00
# 19    15568982  Female   24       0.00
# 23    15725737    Male   46       0.00
# 13    15691483  Female   25       0.00
# 17    15788218  Female   24       0.00
# 27    15700772    Male   44       0.00
# 0     15634602  Female   42       0.00
# 14    15600882  Female   35       0.00

# %%
join_df2 = df[['CustomerId','Surname','Location','EstimatedSalary']]
join_df2 = join_df2.head(20)
join_df2
# Out:
#     CustomerId    Surname Location  EstimatedSalary
# 0     15634602   Hargrave   France        101348.88
# 1     15647311       Hill    Spain        112542.58
# 2     15619304       Onio   France        113931.57
# 3     15701354       Boni   France         93826.63
# 4     15737888   Mitchell    Spain         79084.10
# 5     15574012        Chu    Spain        149756.71
# 6     15592531   Bartlett   France         10062.80
# 7     15656148     Obinna  Germany        119346.88
# 8     15792365         He   France         74940.50
# 9     15592389         H?   France         71725.73
# 10    15767821     Bearce   France         80181.12
# 11    15737173    Andrews    Spain         76390.01
# 12    15632264        Kay   France         26260.98
# 13    15691483       Chin   France        190857.79
# 14    15600882      Scott    Spain         65951.65
# 15    15643966    Goforth  Germany         64327.26
# 16    15737452      Romeo  Germany          5097.67
# ...

# %%
pd.merge(left = join_df,right = join_df2,how = 'inner',on = 'CustomerId')
# Out:
#    CustomerId  Gender  Age    Balance    Surname Location  EstimatedSalary
# 0    15701354  Female   39       0.00       Boni   France         93826.63
# 1    15656148  Female   29  115046.74     Obinna  Germany        119346.88
# 2    15592389    Male   27  134603.88         H?   France         71725.73
# 3    15788218  Female   24       0.00  Henderson    Spain         14406.41
# 4    15634602  Female   42       0.00   Hargrave   France        101348.88

# %%
join_df.rename(columns = {'CustomerId' : 'Id'},inplace = True)

# %%
join_df
# Out:
#           Id  Gender  Age    Balance
# 20  15577657    Male   41       0.00
# 3   15701354  Female   39       0.00
# 38  15717426    Male   36       0.00
# 39  15585768    Male   41   70349.48
# 7   15656148  Female   29  115046.74
# 9   15592389    Male   27  134603.88
# 17  15788218  Female   24       0.00
# 36  15788448    Male   31  145260.23
# 34  15732963  Female   29       0.00
# 0   15634602  Female   42       0.00

# %%
pd.merge(left = join_df,right = join_df2,how = 'outer',left_on = 'Id',right_on = 'CustomerId')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14528\857854307.py in <module>
# ----> 1 pd.merge(left = join_df,right = join_df2,how = 'outer')
#
# ~\anaconda\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# ~\anaconda\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     680             warnings.warn(msg, FutureWarning, stacklevel=find_stack_level())
#     681
# --> 682         self._validate_specification()
#     683
# ...

# %%
pd.merge(left = join_df,right = join_df2,how = 'cross')
# Out:
#            Id  Gender  Age  Balance  CustomerId    Surname Location  \
# 0    15577657    Male   41      0.0    15634602   Hargrave   France
# 1    15577657    Male   41      0.0    15647311       Hill    Spain
# 2    15577657    Male   41      0.0    15619304       Onio   France
# 3    15577657    Male   41      0.0    15701354       Boni   France
# 4    15577657    Male   41      0.0    15737888   Mitchell    Spain
# ..        ...     ...  ...      ...         ...        ...      ...
# 195  15634602  Female   42      0.0    15643966    Goforth  Germany
# 196  15634602  Female   42      0.0    15737452      Romeo  Germany
# 197  15634602  Female   42      0.0    15788218  Henderson    Spain
# 198  15634602  Female   42      0.0    15661507    Muldrow    Spain
# 199  15634602  Female   42      0.0    15568982        Hao   France
#
#      EstimatedSalary
# 0          101348.88
# 1          112542.58
# 2          113931.57
# 3           93826.63
# 4           79084.10
# ...

# %%
join_df
# Out:
#           Id  Gender  Age    Balance
# 20  15577657    Male   41       0.00
# 3   15701354  Female   39       0.00
# 38  15717426    Male   36       0.00
# 39  15585768    Male   41   70349.48
# 7   15656148  Female   29  115046.74
# 9   15592389    Male   27  134603.88
# 17  15788218  Female   24       0.00
# 36  15788448    Male   31  145260.23
# 34  15732963  Female   29       0.00
# 0   15634602  Female   42       0.00

# %%
join_df2
# Out:
#     CustomerId    Surname Location  EstimatedSalary
# 0     15634602   Hargrave   France        101348.88
# 1     15647311       Hill    Spain        112542.58
# 2     15619304       Onio   France        113931.57
# 3     15701354       Boni   France         93826.63
# 4     15737888   Mitchell    Spain         79084.10
# 5     15574012        Chu    Spain        149756.71
# 6     15592531   Bartlett   France         10062.80
# 7     15656148     Obinna  Germany        119346.88
# 8     15792365         He   France         74940.50
# 9     15592389         H?   France         71725.73
# 10    15767821     Bearce   France         80181.12
# 11    15737173    Andrews    Spain         76390.01
# 12    15632264        Kay   France         26260.98
# 13    15691483       Chin   France        190857.79
# 14    15600882      Scott    Spain         65951.65
# 15    15643966    Goforth  Germany         64327.26
# 16    15737452      Romeo  Germany          5097.67
# ...

# %%
join_df.append([join_df2])
# Out:
# C:\Users\gaura\AppData\Local\Temp\ipykernel_14528\35129233.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   join_df.append([join_df2])
#             Id  Gender   Age    Balance  CustomerId    Surname Location  \
# 20  15577657.0    Male  41.0       0.00         NaN        NaN      NaN
# 3   15701354.0  Female  39.0       0.00         NaN        NaN      NaN
# 38  15717426.0    Male  36.0       0.00         NaN        NaN      NaN
# 39  15585768.0    Male  41.0   70349.48         NaN        NaN      NaN
# 7   15656148.0  Female  29.0  115046.74         NaN        NaN      NaN
# 9   15592389.0    Male  27.0  134603.88         NaN        NaN      NaN
# 17  15788218.0  Female  24.0       0.00         NaN        NaN      NaN
# 36  15788448.0    Male  31.0  145260.23         NaN        NaN      NaN
# 34  15732963.0  Female  29.0       0.00         NaN        NaN      NaN
# ...

# %%
pd.concat([join_df,join_df2],axis = 1)
# Out:
#     CustomerId  Gender   Age    Balance  CustomerId    Surname Location  \
# 9   15592389.0    Male  27.0  134603.88  15592389.0         H?   France
# 22  15699309.0  Female  38.0       0.00         NaN        NaN      NaN
# 3   15701354.0  Female  39.0       0.00  15701354.0       Boni   France
# 19  15568982.0  Female  24.0       0.00  15568982.0        Hao   France
# 23  15725737.0    Male  46.0       0.00         NaN        NaN      NaN
# 13  15691483.0  Female  25.0       0.00  15691483.0       Chin   France
# 17  15788218.0  Female  24.0       0.00  15788218.0  Henderson    Spain
# 27  15700772.0    Male  44.0       0.00         NaN        NaN      NaN
# 0   15634602.0  Female  42.0       0.00  15634602.0   Hargrave   France
# 14  15600882.0  Female  35.0       0.00  15600882.0      Scott    Spain
# 1          NaN     NaN   NaN        NaN  15647311.0       Hill    Spain
# 2          NaN     NaN   NaN        NaN  15619304.0       Onio   France
# ...

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Location  Gender  Age  \
# 0             1    15634602   Hargrave          619   France  Female   42
# 1             2    15647311       Hill          608    Spain  Female   41
# 2             3    15619304       Onio          502   France  Female   42
# 3             4    15701354       Boni          699   France  Female   39
# 4             5    15737888   Mitchell          850    Spain  Female   43
# ...         ...         ...        ...          ...      ...     ...  ...
# 9995       9996    15606229   Obijiaku          771   France    Male   39
# 9996       9997    15569892  Johnstone          516   France    Male   35
# 9997       9998    15584532        Liu          709   France  Female   36
# 9998       9999    15682355  Sabbatini          772  Germany    Male   42
# 9999      10000    15628319     Walker          792   France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.loc[df['CustomerId']==15647311]
# Out:
#    RowNumber  CustomerId Surname  CreditScore Location  Gender  Age  Tenure  \
# 1          2    15647311    Hill          608    Spain  Female   41       1
#
#     Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 1  83807.86              1          0               1        112542.58
#
#    Exited  Bhoomi      Bonus
# 1       0       0  225085.16

# %%
df.loc[df['Age'] > 40,['Surname',"Age"]]
# Out:
#           Surname  Age
# 0        Hargrave   42
# 1            Hill   41
# 2            Onio   42
# 4        Mitchell   43
# 5             Chu   44
# ...           ...  ...
# 9981     Burbidge   42
# 9982      Griffin   46
# 9986     Bartlett   47
# 9991  Ajuluchukwu   53
# 9998    Sabbatini   42
#
# [3581 rows x 2 columns]

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Location  Gender  Age  \
# 0             1    15634602   Hargrave          619   France  Female   42
# 1             2    15647311       Hill          608    Spain  Female   41
# 2             3    15619304       Onio          502   France  Female   42
# 3             4    15701354       Boni          699   France  Female   39
# 4             5    15737888   Mitchell          850    Spain  Female   43
# ...         ...         ...        ...          ...      ...     ...  ...
# 9995       9996    15606229   Obijiaku          771   France    Male   39
# 9996       9997    15569892  Johnstone          516   France    Male   35
# 9997       9998    15584532        Liu          709   France  Female   36
# 9998       9999    15682355  Sabbatini          772  Germany    Male   42
# 9999      10000    15628319     Walker          792   France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.iloc[3]
# Out:
# RowNumber                  4
# CustomerId          15701354
# Surname                 Boni
# CreditScore              699
# Location              France
# Gender                Female
# Age                       39
# Tenure                     1
# Balance                  0.0
# NumOfProducts              2
# HasCrCard                  0
# IsActiveMember             0
# EstimatedSalary     93826.63
# Exited                     0
# Bhoomi                     0
# Bonus              187653.26
# Name: 3, dtype: object

# %%
 # head, tail
 # Info 
 # rename all columns 
 # create new columns - bonus = 2* EstimatedSalary
 # sorting 
 # find all columns
 # find shape
 # find unique values and number of unique values - all columns
 # use value_count, unique, nunique method
 # sorting - ascending, descending
 # isna/ isnull
 # drop_duplicates
 # fillna
 # drop_na
 # drop
 # describe
 # sum , count
 # reset_index
 # duplicated
 # groupby 
 # merge - Left, right, cross, inner, outer

# %%
temp_df1 = df.head(10)
temp_df2 = df.head(10)
temp_df1.shape
# Out:
# (10, 14)

# %%
pd.concat([temp_df1,temp_df2],axis = 0)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# ...

# %%
pd.concat([temp_df1,temp_df2],axis = 0).shape
# Out:
# (20, 14)

# %%
pd.concat([temp_df1,temp_df2],axis = 1)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619     France  Female   42
# 1          2    15647311      Hill          608      Spain  Female   41
# 2          3    15619304      Onio          502     France  Female   42
# 3          4    15701354      Boni          699     France  Female   39
# 4          5    15737888  Mitchell          850      Spain  Female   43
# 5          6    15574012       Chu          645      Spain    Male   44
# 6          7    15592531  Bartlett          822     France    Male   50
# 7          8    15656148    Obinna          376    Germany  Female   29
# 8          9    15792365        He          501     France    Male   44
# 9         10    15592389        H?          684     France    Male   27
#
#    Tenure    Balance  NumOfProducts  ...  Geography  Gender  Age  Tenure  \
# 0       2       0.00              1  ...     France  Female   42       2
# ...

# %%
pd.concat([temp_df1,temp_df2],axis = 1).shape
# Out:
# (10, 28)
